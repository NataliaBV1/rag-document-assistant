# %% [markdown]
# # 01 - Chunking experiments
#
# Compare chunking strategies (fixed size, overlap, semantic) and measure their effect on Hit Rate and MRR. Use the findings to fill in the results table in the README.

# %%
# TODO: load config, vary chunk_size/overlap, rebuild index and evaluate.
